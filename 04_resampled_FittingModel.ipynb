# %%
import pandas as pd 
import numpy as np
from sklearn.linear_model import SGDClassifier
from sklearn.metrics import ConfusionMatrixDisplay
from sklearn.metrics import confusion_matrix
from sklearn.model_selection import train_test_split

# %%
# %store -r X_resampled
# %store -r y_resampled
X_train, X_test, y_train, y_test = train_test_split(X_resampled, y_resampled, test_size=0.20)

# %%
sdgc_clf = SGDClassifier()
sdgc_clf.fit(X_train,y_train)
y_pred = sdgc_clf.predict(X_test)
sdgc_clf.score(X_test,y_test)
# Out:
# 0.7475708384243905

# %%
cm = confusion_matrix(y_test,y_pred)
print(cm)
display = ConfusionMatrixDisplay(confusion_matrix=cm)
display.plot()
# Out:
# [[11192  6076]
#  [ 2601 14505]]

# %% [markdown]
# ## From the confusion matrix we can observe that the structure of prediction has changed. Now FalseNegative has the least amount of predicitions, which is the most deserved situation.
# Now it is desired to increase the accuracy of the model:
# For that we have couple of approaches.
# We can try with different model(kernel approximations) or we can try to tune the hyperparameters
